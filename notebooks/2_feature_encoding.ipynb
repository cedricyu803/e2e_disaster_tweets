# %%
import sys
sys.path.append('..')

import os
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
# pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', None)

from sklearn.model_selection import train_test_split

from src.features.preprocessing_utils import df_preprocess_text
from src.features.feature_engineering_utils import df_get_features
from src.features.feature_encoding_utils import fit_encoders, transform_features


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
train = pd.read_csv ("../train.csv", header = [0])[['text', 'target']]
X_test = pd.read_csv ("../test.csv", header = [0])[['text']]
X_train, X_valid, y_train, y_valid = train_test_split(train.drop(['target'], axis = 1), train['target'], random_state=0, train_size = 0.8)

# %%
X_train_text_processed = df_preprocess_text(X_train)
X_valid_text_processed = df_preprocess_text(X_valid)
X_test_text_processed = df_preprocess_text(X_test)

# %%
X_train_text_processed.head()
# Out:
#                                                                                                                                            text  \
# 1386            Ted Cruz fires back at Jeb &amp; Bush: ÛÏWe lose because of Republicans like Jeb &amp; Mitt.Û [Video] http://t.co/FgDEh56PLO
# 4048  This is the first year the Forest Service spent more than half its annual budget on fighting fires. #climatechange http://t.co/D62zfZy0Mi
# 3086                                                          @lightseraphs pissed at you and could have their pikachu electrocute you and :\\\
# 272                                                                                              I'm gonna fight Taylor as soon as I get there.
# 7462                                               @NicolaClements4 IÛªm not sure that covering my head in wounds and scabs is the solution ;)
#
#                                                                                                                                text_no_mojibake  \
# 1386                    Ted Cruz fires back at Jeb & Bush: ÛÏWe lose because of Republicans like Jeb & Mitt.Û [Video] http://t.co/FgDEh56PLO
# 4048  This is the first year the Forest Service spent more than half its annual budget on fighting fires. #climatechange http://t.co/D62zfZy0Mi
# 3086                                                          @lightseraphs pissed at you and could have their pikachu electrocute you and :\\\
# 272                                                                                              I'm gonna fight Taylor as soon as I get there.
# 7462                                               @NicolaClements4 IÛªm not sure that covering my head in wounds and scabs is the solution ;)
#
#                                                                                                                             text_processed
# 1386  Ted Cruz fires back at Jeb <punc> Bush <punc> ÛÏWe lose because of Republicans like Jeb <punc> Mitt . Û <punc> Video <punc> <url>
# 4048    This is the first year the Forest Service spent more than half its annual budget on fighting fires . <hashtag> climatechange <url>
# 3086                                                          <user> pissed at you and could have their pikachu electrocute you and <punc>
# 272                                                                                 I <punc> m gonna fight Taylor as soon as I get there .
# 7462                                                <user> IÛªm not sure that covering my head in wounds and scabs is the solution <punc>

# %%
X_test_text_processed.head()
# Out:
#                                                                                                text  \
# 0                                                                Just happened a terrible car crash
# 1                                  Heard about #earthquake is different cities, stay safe everyone.
# 2  there is a forest fire at spot pond, geese are fleeing across the street, I cannot save them all
# 3                                                          Apocalypse lighting. #Spokane #wildfires
# 4                                                     Typhoon Soudelor kills 28 in China and Taiwan
#
#                                                                                    text_no_mojibake  \
# 0                                                                Just happened a terrible car crash
# 1                                  Heard about #earthquake is different cities, stay safe everyone.
# 2  there is a forest fire at spot pond, geese are fleeing across the street, I cannot save them all
# 3                                                          Apocalypse lighting. #Spokane #wildfires
# 4                                                     Typhoon Soudelor kills 28 in China and Taiwan
#
#                                                                                                  text_processed
# 0                                                                            Just happened a terrible car crash
# 1                              Heard about <hashtag> earthquake is different cities <punc> stay safe everyone .
# 2  there is a forest fire at spot pond <punc> geese are fleeing across the street <punc> I cannot save them all
# 3                                                   Apocalypse lighting . <hashtag> Spokane <hashtag> wildfires
# 4                                                           Typhoon Soudelor kills <number> in China and Taiwan

# %%
X_train_features = df_get_features(X_train_text_processed)

# %%
X_valid_features = df_get_features(X_valid_text_processed)
X_test_features = df_get_features(X_test_text_processed)

# %%
X_valid_features.head()
# Out:
#                                                                                                                                               text  \
# 311                                                                 @KatieKatCubs you already know how this shit goes. World Series or Armageddon.
# 4970  @LeMaireLee @danharmon People Near Meltdown Comics Who Have Free Time to Wait in Line on Sunday Nights are not a representative sample. #140
# 527                                            1-6 TIX Calgary Flames vs COL Avalanche Preseason 9/29 Scotiabank Saddledome http://t.co/5G8qA6mPxm
# 6362                   If you ever think you running out of choices in life rembr there's that kid that has no choice but wear a suicide bomb vest
# 800                                                                           If you dotish to blight your car go right ahead. Once it's not mine.
#
#                                                                                                                                   text_no_mojibake  \
# 311                                                                 @KatieKatCubs you already know how this shit goes. World Series or Armageddon.
# 4970  @LeMaireLee @danharmon People Near Meltdown Comics Who Have Free Time to Wait in Line on Sunday Nights are not a representative sample. #140
# 527                                            1-6 TIX Calgary Flames vs COL Avalanche Preseason 9/29 Scotiabank Saddledome http://t.co/5G8qA6mPxm
# 6362                   If you ever think you running out of choices in life rembr there's that kid that has no choice but wear a suicide bomb vest
# 800                                                                           If you dotish to blight your car go right ahead. Once it's not mine.
#
#                                                                                                                                                             text_processed  \
# 311                                                                                              <user> you already know how this shit goes . World Series or Armageddon .
# 4970  <user> <user> People Near Meltdown Comics Who Have Free Time to Wait in Line on Sunday Nights are not a representative sample . <hashtag> <number> <number> <number>
# 527                                                   <number> <number> TIX Calgary Flames vs COL Avalanche Preseason <number> <punc> <number> Scotiabank Saddledome <url>
# 6362                                           If you ever think you running out of choices in life rembr there s that kid that has no choice but wear a suicide bomb vest
# 800                                                                                                 If you dotish to blight your car go right ahead . Once it s not mine .
#
#       char_count  punc_ratio  cap_ratio  sentence_count  stopword_num  \
# 311           78    0.038462   0.076923               2             4
# 4970         140    0.028571   0.107143               2             6
# 527           99    0.070707   0.151515               1             0
# 6362         123    0.008130   0.008130               1            13
# 800           68    0.044118   0.029412               2             6
#
#      hashtags  hashtag_num                       at  at_num  \
# 311        []            0           [KatieKatCubs]       1
# 4970    [140]            1  [LeMaireLee, danharmon]       2
# 527        []            0                       []       0
# 6362       []            0                       []       0
# 800        []            0                       []       0
#
#                            url  url_num  country_mention_num  token_count
# 311                         []        0                    0           16
# 4970                        []        0                    0           39
# 527   [http://t.co/5G8qA6mPxm]        1                    0           27
# 6362                        []        0                    0           26
# 800                         []        0                    0           17
